# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.io.json import json_normalize

# %%
import time
import warnings
warnings.filterwarnings(action='ignore')
from IPython.display import Image
import os

# %%
# 폰트 깨짐방지
import matplotlib.font_manager as fm
fm.findSystemFonts(fontpaths=None, fontext='ttf')
plt.rc('font', family='D2Coding')

# %%
# 데이터 불러오기
dfpc = pd.read_csv('C:/Users/snm03/Documents/debbu/gameData/the_log_data_manufac_csv/the_log_weeknum.csv')
dfpc
# Out:
#       Unnamed: 0.1  index_num  num_week  Unnamed: 0  rank           name  \
# 0                0          0         0           0     1         배틀그라운드
# 1                1          1         0           2     2      리그 오브 레전드
# 2                2          2         0           4     3           오버워치
# 3                3          3         0           6     4           서든어택
# 4                4          4         0           8     5         던전앤파이터
# ...            ...        ...       ...         ...   ...            ...
# 8575          8575       8575         0          50    26           검은사막
# 8576          8576       8576         0          52    27      블레이드 & 소울
# 8577          8577       8577         0          54    28       크레이지아케이드
# 8578          8578       8578         0          56    29            엘소드
# 8579          8579       8579         0          58    30  카운터-스트라이크 온라인
#
#      genre  genre_share pc_room_num total_time_hour  mean_time_min  \
# ...

# %%
# data에서 genre 언급량보기
dfpc_genre = dfpc.groupby('genre')['genre'].count()
dfpc_genre = dfpc_gro.sort_values(ascending=False)
dfpc_genre
# Out:
# genre
# RPG     3140
# FPS     1617
# RTS     1485
# 액션      1005
# 스포츠      537
# 레이싱      286
# 아케이드     272
# 보드       225
# 슈팅         8
# 캐주얼        5
# Name: genre, dtype: int64

# %%
# 시리즈->판다스
dfpc_genre = pd.DataFrame(dfpc_genre)
dfpc_genre
# Out:
#        genre
# genre
# RPG     3140
# FPS     1617
# RTS     1485
# 액션      1005
# 스포츠      537
# 레이싱      286
# 아케이드     272
# 보드       225
# 슈팅         8
# 캐주얼        5

# %%
# 컬럼 변경
a = dfpc_genre.columns = ['count']
a
# Out:
# ['count']

# %%
# 인덱스 리셋
a = dfpc_genre.reset_index() 
a
# Out:
#   genre  count
# 0   RPG   3140
# 1   FPS   1617
# 2   RTS   1485
# 3    액션   1005
# 4   스포츠    537
# 5   레이싱    286
# 6  아케이드    272
# 7    보드    225
# 8    슈팅      8
# 9   캐주얼      5

# %%
a.plot.bar(x='genre', y='count')
# Out:
# <AxesSubplot:xlabel='genre'>
